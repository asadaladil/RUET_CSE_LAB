# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# given poles, zeros, ROC(a)

poles=np.arange(1,10,2)
zeros=np.arange(2,10,2)

p0=np.linspace(-poles[0],poles[0],1000)
p1=np.linspace(-poles[1],poles[1],1000)
p2=np.linspace(-poles[2],poles[2],1000)
p3=np.linspace(-poles[3],poles[3],1000)
p4=np.linspace(-poles[4],poles[4],1000)

# c1=list(np.sqrt(poles[0]**2-p0**2))+list((-1)*np.sqrt(poles[0]**2-p0**2))
# c2=list(np.sqrt(poles[1]**2-p1**2))+list((-1)*np.sqrt(poles[1]**2-p1**2))
# c3=list(np.sqrt(poles[2]**2-p2**2))+list((-1)*np.sqrt(poles[2]**2-p2**2))
# c4=list(np.sqrt(poles[3]**2-p3**2))+list((-1)*np.sqrt(poles[3]**2-p3**2))
# c5=list(np.sqrt(poles[4]**2-p4**2))+list((-1)*np.sqrt(poles[4]**2-p4**2))

plt.figure(figsize=(12,12))

plt.plot(np.sin(p0),np.cos(p0))
plt.plot(np.sin(p1),np.cos(p1))
plt.plot(np.sin(p2),np.cos(p2))
plt.plot(np.sin(p3),np.cos(p3))
plt.plot(np.sin(p4),np.cos(p4))

plt.show()
